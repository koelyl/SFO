# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 28 days

# %%
data = pd.read_csv("2016-SFO-Customer-Survey-Data.csv")
#Show all columns when displaying dataframe
pd.set_option('display.max_columns', 97)

# %%
data.head()
# Out:
#    *RESPNUM  CCGID  RUNID  INTDATE  EGYPTAIR  DAY  GATE BAREA  STRATA  PEAK  \
# 0        17     84    610    42501         1    4    42     C       3     2
# 1        70     40    576    42499         1    2    26     B       3     2
# 2      1512   1992    745    42505         1    1    12     A       3     2
# 3      1932   1869    759    42506         1    2    91     G       3     3
# 4      2408   2734    514    42496         1    6    54     D       2     2
#
#    METHOD  SAQ         AIRLINE     DESTINATION  FLIGHT  AIRLINE CODE  \
# 0       1    2           DELTA  SALT LAKE CITY    2800            15
# 1       1    2       SOUTHWEST     LOS ANGELES    2034            25
# 2       1    2         JETBLUE      LONG BEACH    1635            20
# 3       1    2     UNITED INTL    TOKYO-HANEDA     875            29
# 4       1    2  VIRGIN AMERICA     LOS ANGELES     932            30
#
#    DEST CODE  DESTGEO  DESTMARK   ARRTIME   DEPTIME HOWLONG  Q2PURP1  Q2PURP2  \
# ...

# %% [markdown]
# <h2>Cleaning Data</h2>

# %%
#Drop unnecessary variables
data = data.drop(["*RESPNUM","CCGID", "RUNID", "DAY", "INTDATE", "EGYPTAIR", "SAQ", "DEST CODE", 
                 "AIRLINE CODE", "STRATA", "PEAK", "GATE", "METHOD", "FLIGHT", "LANG", "WEIGHT", "FLIGHT", "DESTGEO",
                 "Q3GETTO1", "Q3GETTO2", "Q3GETTO3", "Q3PARK", "Q8COM", "Q8COM2", "Q8COM3", "Q8COM4", "Q8COM5", 
                  "Q9COM", "Q9COM2", "Q9COM3", "Q10COM1", "Q10COM2", "Q10COM3", "Q12PRECOM1", "Q12PRECOM2", "Q12PRECOM3", 
                 "Q15COM1", "Q15COM2", "Q15COM3", "ARRTIME", "DEPTIME"], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-14eeb10aab07> in <module>()
#       4                  "Q3GETTO1", "Q3GETTO2", "Q3GETTO3", "Q3PARK", "Q8COM", "Q8COM2", "Q8COM3", "Q8COM4", "Q8COM5",
#       5                   "Q9COM", "Q9COM2", "Q9COM3", "Q10COM1", "Q10COM2", "Q10COM3", "Q12PRECOM1", "Q12PRECOM2", "Q12PRECOM3",
# ----> 6                  "Q15COM1", "Q15COM2", "Q15COM3", "ARRTIME", "DEPTIME"], axis = 1)
#
# /Users/KoryLyles/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    1875                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1876             else:
# -> 1877                 new_axis = axis.drop(labels, errors=errors)
#    1878             dropped = self.reindex(**{axis_name: new_axis})
#    1879             try:
#
# ...
